# %% [markdown]
# <a href="https://colab.research.google.com/github/kailee0422/Big-Data/blob/master/assessment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)

# %%
NBA1819<-fetch_NBAPlayerStatistics("18-19")

# %%
head(NBA1819)
# Out:
#   League Name         Team Position GamesPlayed TotalMinutesPlayed
# 1 NBA    Alex Abrines OKL  SG       31           588
# 2 NBA    Quincy Acy   PHO  SF       10           121
# 3 NBA    Jaylen Adams ATL  PG       34           425
# 4 NBA    Steven Adams OKL  C        80          2667
# 5 NBA    Bam Adebayo  MIA  C        82          1908
# 6 NBA    Deng Adel    CLE  SF       18           196
#   FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 1  56            157                 41         127             ⋯  17
# 2   4             18                  2          15             ⋯   1
# 3  38            110                 25          74             ⋯  13
# 4 481            809                  0           2             ⋯ 119
# 5 280            487                  3          15             ⋯  72
# 6  11             36                  6          23             ⋯   1
#   Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# ...

# %%
head(NBA1819,n=20)
# Out:
#    League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1  NBA    Alex Abrines     OKL  SG       31           588
# 2  NBA    Quincy Acy       PHO  SF       10           121
# 3  NBA    Jaylen Adams     ATL  PG       34           425
# 4  NBA    Steven Adams     OKL  C        80          2667
# 5  NBA    Bam Adebayo      MIA  C        82          1908
# 6  NBA    Deng Adel        CLE  SF       18           196
# 7  NBA    De Akoon-purcell DEN  SG        7            23
# 8  NBA    Lamarcu Aldridge SAN  PF       81          2689
# 9  NBA    Rawle Alkins     CHI  SG       10           120
# 10 NBA    Grayson Allen    UTA  SG       37           414
# 11 NBA    Jarrett Allen    BRO  C        80          2095
# 12 NBA    Kadeem Allen     NYK  SG       19           414
# 13 NBA    Al-farouq Aminu  POR  PF       81          2289
# 14 NBA    Justin Anderson  ATL  SG       46           460
# 15 NBA    Kyle Anderson    MEM  SF       43          1281
# ...

# %%
NBA1819Order<-NBA1819[order(NBA1819$GamesPlayed,decreasing = T),]
NBA1819Order[1:30, ]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 5   NBA    Bam Adebayo      MIA  C        82          1908
# 40  NBA    Bradley Beal     WAS  SG       82          3025
# 45  NBA    Deandre' Bembry  ATL  SF       82          1930
# 66  NBA    Mikal Bridges    PHO  SF       82          2418
# 87  NBA    Ke Caldwell-pope LAL  SG       82          2031
# 169 NBA    Bryn Forbes      SAN  SG       82          2288
# 186 NBA    Gilgeous-alexand LAC  PG       82          2174
# 208 NBA    Montrezl Harrell LAC  PF       82          2158
# 212 NBA    Tobias Harris    PHI  PF       82          2847
# 224 NBA    Buddy Hield      SAC  SG       82          2614
# 231 NBA    Justin Holiday   MEM  SG       82          2608
# 246 NBA    Joe Ingles       UTA  SF       82          2564
# 257 NBA    Reggie Jackson   DET  PG       82          2284
# 277 NBA    Cory Joseph      IND  PG       82          2061
# 350 NBA    Patty Mills      SAN  PG       82          1908
# ...

# %%
subset(NBA1819,Team=="GSW")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 44  NBA    Jordan Bell      GSW  PF       67           790
# 58  NBA    Andrew Bogut     GSW  C        11           135
# 114 NBA    Quinn Cook       GSW  PG       72          1063
# 115 NBA    Demarcus Cousins GSW  C        30           772
# 124 NBA    Stephen Curry    GSW  PG       69          2328
# 136 NBA    Marcu Derrickson GSW  PF       11            68
# 150 NBA    Kevin Durant     GSW  SF       78          2703
# 158 NBA    Jacob Evans      GSW  SG       27           199
# 198 NBA    Draymond Green   GSW  PF       66          2064
# 244 NBA    Andre Iguodala   GSW  SG       68          1574
# 261 NBA    Jonas Jerebko    GSW  PF       73          1221
# 270 NBA    Damian Jones     GSW  C        24           410
# 298 NBA    Damion Lee       GSW  SG       32           375
# 307 NBA    Shaun Livingston GSW  PG       64           965
# 309 NBA    Kevon Looney     GSW  SF       80          1476
# ...

# %%
NBA1819[grepl("Curry",NBA1819$Name),]
# Out:
#     League Name          Team Position GamesPlayed TotalMinutesPlayed
# 123 NBA    Seth Curry    POR  SG       74          1402
# 124 NBA    Stephen Curry GSW  PG       69          2328
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 123 212             465                113        251             ⋯ 35
# 124 632            1340                354        810             ⋯ 92
#     Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 123  61       12      97           0                  581        0
# 124 192       26     166           0                 1881        2
#     Ejections FlagrantFouls GamesStarted
# 123 0         0              2
# 124 0         0             69

# %%
install.packages("data.table")
library(data.table)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
NBA1819DT<-data.table(NBA1819)


NBA1819DT[grepl('James',Name)]
NBA1819DT[GamesPlayed>80]
NBA1819DT[grepl('C',Name)&Position=="PG"]
# Out:
#   League Name           Team Position GamesPlayed TotalMinutesPlayed
# 1 NBA    James Ennis    PHI  SF       58          1229
# 2 NBA    James Harden   HOU  PG       78          2870
# 3 NBA    Lebron James   LAL  PF       55          1935
# 4 NBA    James Johnson  MIA  PF       55          1164
# 5 NBA    James Nunnally HOU  SF       15           102
#   FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 1 138             294                 55         156            ⋯  41
# 2 843            1909                378        1028            ⋯ 158
# 3 558            1095                111         327            ⋯  72
# 4 164             379                 50         149            ⋯  35
# 5  12              34                  8          25            ⋯   1
#   Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 1  35       24     150           0                  389        1
# ...

# %%
NBA1819DT[TotalPoints>150]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Alex Abrines     OKL  SG       31           588
# 2   NBA    Steven Adams     OKL  C        80          2667
# 3   NBA    Bam Adebayo      MIA  C        82          1908
# 4   NBA    Lamarcu Aldridge SAN  PF       81          2689
# 5   NBA    Grayson Allen    UTA  SG       37           414
# 6   NBA    Jarrett Allen    BRO  C        80          2095
# 7   NBA    Kadeem Allen     NYK  SG       19           414
# 8   NBA    Al-farouq Aminu  POR  PF       81          2289
# 9   NBA    Justin Anderson  ATL  SG       46           460
# 10  NBA    Kyle Anderson    MEM  SF       43          1281
# 11  NBA    Gi Antetokounmpo MIL  PF       72          2358
# 12  NBA    Og Anunoby       TOR  SF       67          1358
# 13  NBA    Ryan Arcidiacono CHI  PG       81          1960
# 14  NBA    Trevor Ariza     WAS  SF       69          2349
# 15  NBA    D.j. Augustin    ORL  PG       81          2269
# ...
